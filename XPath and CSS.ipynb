# %%
"""
More Web Scraping
DataCamp
"""

# %%
"""XPath navigation"""

# %%
"""Slashes and brackets"""
# Single forward sales / looks forward one generation
# Double forward slash // looks forward all future generations
# Square brackets [] help narrow in on specific elements
# Asterisk * is the wildcard

# %%
"""CSS Locators"""

# %%
# XPath - /html/body/div
# CSS Locator - html > body > div

# XPath - //div/span//p
# CSS Locator - div > span p

# XPath - //div/p[2]
# CSS Locator - div > p:nth-of-type(2)

# %%
"Attributes in CSS"
# To find element by class, use '.'
# p.class-1 selects all paragraph elements of class-1

# To find element by id, use '#'
# div#uid selects div element with id equal to uid

# %%
"""Attribute and text selection"""

# %%
"""Using colons"""
# XPath - '//div[@id="uid"]/a/@href'
# CSS Locator - 'div#uid > a::attr(href}'

# %%
"""Text extraction"""

# %%
sel.xpath('//p[@id="p-example"]/text()').extract()
sel.css('p#p-example::text').extract()
# result - ['\n Hello world!\n Try ', ' today!\n']

sel.xpath('//p[@id="p-example"]//text()').extract()
sel.css('p#p-example ::text').extract()
# result - ['\n Hello world!\n Try ', 'DataCamp', ' today!\n']

# %%
"""Response objects"""
# Remembers URL, adding crawling capability between sites
